# %% [markdown]
# # List of Packages to Download
#
# ```python
# !pip install langchain-chroma
# !pip install langchain
# !pip install langchain_community
# !pip install langchainhub
# !pip install --upgrade --quiet  gpt4all > /dev/null

# %%
# !pip install langchain-chroma
# !pip install langchain
# !pip install langchain_community
# !pip install langchainhub
# !pip install gpt4all
# Out:
# Requirement already satisfied: langchain-chroma in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (0.1.1)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-chroma) (0.5.0)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-chroma) (0.111.0)
# Requirement already satisfied: langchain-core<0.3,>=0.1.40 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-chroma) (0.2.9)
# Requirement already satisfied: numpy<2,>=1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-chroma) (1.26.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.1)
# Requirement already satisfied: requests>=2.28 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.7.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.30.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.64.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.10.3)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (2.1.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma) (0.1.81)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.1.0)
# Requirement already satisfied: colorama in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (7.0.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.1)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma) (3.7)
# Requirement already satisfied: anyio in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (4.2.0)
# Requirement already satisfied: certifi in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.40->langchain-chroma) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: coloredlogs in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.20.3)
# Requirement already satisfied: sympy in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests>=2.28->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.23.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma) (12.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from importlib-resources->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from anyio->httpx>=0.23.0->fastapi<1,>=0.95.2->langchain-chroma) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: filelock in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (2.15.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma) (0.6.0)
# Requirement already satisfied: langchain in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (0.2.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (0.2.9)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (0.1.81)
# Requirement already satisfied: numpy<2,>=1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (2.7.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain) (2.4)
# Requirement already satisfied: langchain_community in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (0.2.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (0.2.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (0.2.9)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (0.1.81)
# Requirement already satisfied: numpy<2,>=1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (1.26.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain<0.3.0,>=0.2.5->langchain_community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain<0.3.0,>=0.2.5->langchain_community) (2.7.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.5->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.5->langchain_community) (2.18.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: langchainhub in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (0.1.20)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchainhub) (23.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchainhub) (2.32.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from langchainhub) (2.32.0.20240622)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchainhub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchainhub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests<3,>=2->langchainhub) (2024.2.2)
# Requirement already satisfied: gpt4all in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (2.7.0)
# Requirement already satisfied: requests in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from tqdm->gpt4all) (0.4.6)

# %%
# !pip install gpt4all
# Out:
# Requirement already satisfied: gpt4all in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (2.7.0)
# Requirement already satisfied: requests in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from gpt4all) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from requests->gpt4all) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\aravind\anaconda3\envs\tf_torch\lib\site-packages (from tqdm->gpt4all) (0.4.6)

# %% [markdown]
# # 1. Get a Data Loader

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
loader = WebBaseLoader("https://www.foxsports.com/nba/lebron-james-player-stats")
data = loader.load()
data
# Out:
# [Document(page_content="\n\n\nLeBron James Stats - NBA | FOX Sports\n\n\n    my favs \n          Access and manage your favorites here\n          \n            DISMISS\n                  Scores Watch UEFA Euro 2024 COPA AMÉRICA Odds Super 6 Stories  \n                  Search\n                     \n                  Sign In\n                    \n                  Account\n                    \n              SPORTS & TEAMS\n             \n              PLAYERS\n             \n              SHOWS\n             \n              PERSONALITIES\n                    SPORTS   \n              SPORTS & TEAMS\n            \n              PLAYERS\n            \n              SHOWS\n            \n              PERSONALITIES\n             \n          SPORTS\n          \n                NFL\n                \n                NCAA FB\n                \n                MLB\n                \n                NBA\n                \n                NCAA BK\n                \n                NASCAR\n                \n                Soccer\n                \n                UFL\n                \n                NCAAW BK\n                \n                NHL\n                \n                Golf\n                \n                Premier Boxing Champions\n                \n                WWE\n                \n                UFC\n                \n                WNBA\n                \n                Tennis\n                \n                Motor Sports\n                \n                Professional Bowlers Association\n                \n                Horse Racing\n                \n                Westminster Kennel Club\n                \n                FIBA\n                \n                Olympics\n                \n                World Baseball Classic\n                \n                NRL\n                \n                The Basketball Tournament\n                    \n      NBA\n     \n      NBA\n      \n              NBA\n              \n              Atlanta Hawks\n              \n              Boston Celtics\n              \n              Brooklyn Nets\n              \n              Charlotte Hornets\n              \n              Chicago Bulls\n              \n              Cleveland Cavaliers\n              \n              Dallas Mavericks\n              \n              Denver Nuggets\n              \n              Detroit Pistons\n              \n              Golden State Warriors\n              \n              Houston Rockets\n              \n              Indiana Pacers\n              \n              LA Clippers\n              \n              Los Angeles Lakers\n              \n              Memphis Grizzlies\n              \n              Miami Heat\n              \n              Milwaukee Bucks\n              \n              Minnesota Timberwolves\n              \n              New Orleans Pelicans\n              \n              New York Knicks\n              \n              Oklahoma City Thunder\n              \n              Orlando Magic\n              \n              Philadelphia 76ers\n              \n              Phoenix Suns\n              \n              Portland Trail Blazers\n              \n              Sacramento Kings\n              \n              San Antonio Spurs\n              \n              Toronto Raptors\n              \n              Utah Jazz\n              \n              Washington Wizards\n                   LEBRON JAMES #23 - SMALL FORWARD - LOS ANGELES LAKERS 25.7\xa0 PPG\xa0 •\n            7.3\xa0 RPG\xa0 •\n            8.3\xa0 APG\xa0   \n          #23 - SMALL FORWARD - LOS ANGELES LAKERS\n          25.7 PPG7.3 RPG8.3 APG     NBA > LOS ANGELES LAKERS > LEBRON JAMES  STATS  \n      NEWS\n    \n      BIO\n    \n      STATS\n    \n      VIDEOS\n    \n      GAME LOG\n    \n      INJURIES\n         \n            SCORING\n             25.7 PPG \n                    13TH IN THE LEAGUE\n                  \n            REBOUNDING\n             7.3 RPG \n                    32ND IN THE LEA ...

# %% [markdown]
# # 2. Convert data to Vector Database

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import GPT4AllEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(data)

# %%
embedding = GPT4AllEmbeddings(model_name="Phi-3-mini-4k-instruct-q4.gguf")
Chroma.from_documents(documents=splits, embedding=embedding, persist_directory="./chroma_db")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 embedding = GPT4AllEmbeddings(model_name="Phi-3-mini-4k-instruct-q4.gguf")
#       2 Chroma.from_documents(documents=splits, embedding=embedding, persist_directory="./chroma_db")
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for GPT4AllEmbeddings
# __root__
#   Request failed: HTTP 404 Not Found (type=value_error)

# %% [markdown]
# # 3. Make a RAG pipeline

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import RetrievalQA
from langchain import hub

# %%
from langchain_community.llms import Ollama

# %%
model_name = "phi3"
llm = Ollama(model=model_name)
prompt = hub.pull("rlm/rag-prompt")
vectorstore = Chroma(persist_directory="./chroma_db", embedding_function=embedding)

# %%
qa_chain = RetrievalQA.from_chain_type(
        llm,
        retriever=vectorstore.as_retriever(),
        chain_type_kwargs={"prompt": prompt}
    )

# %%
question = "Tell me what the stats are saying"
result = qa_chain({"query": question })
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002C8377E26A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002C8377E26A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[42], line 2
#       1 question = "Tell me what the stats are saying"
# ----> 2 result = qa_chain({"query": question })
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\retrieval_qa\base.py:145, in BaseRetrievalQA._call(self, inputs, run_manager)
#     143 else:
#     144     docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 145 answer = self.combine_documents_chain.run(
#     146     input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     147 )
#     149 if self.return_source_documents:
#     150     return {self.output_key: answer, "source_documents": docs}
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:605, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     600     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     601         _output_key
#     602     ]
#     604 if kwargs and not args:
# --> 605     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     606         _output_key
#     607     ]
#     609 if not kwargs and not args:
#     610     raise ValueError(
#     611         "`run` supported with either positional arguments or keyword arguments,"
#     612         " but none were provided."
#     613     )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\combine_documents\base.py:137, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     135 # Other keys are assumed to be needed for LLM prediction
#     136 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137 output, extra_return_dict = self.combine_docs(
#     138     docs, callbacks=_run_manager.get_child(), **other_keys
#     139 )
#     140 extra_return_dict[self.output_key] = output
#     141 return extra_return_dict
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\combine_documents\stuff.py:244, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     242 inputs = self._get_inputs(docs, **kwargs)
#     243 # Call predict on the LLM.
# --> 244 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\llm.py:316, in LLMChain.predict(self, callbacks, **kwargs)
#     301 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     302     """Format prompt with kwargs and pass to LLM.
#     303
#     304     Args:
#    (...)
#     314             completion = llm.predict(adjective="funny")
#     315     """
# --> 316     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\language_models\llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\language_models\llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\language_models\llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_core\language_models\llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_community\llms\ollama.py:417, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     415 generations = []
#     416 for prompt in prompts:
# --> 417     final_chunk = super()._stream_with_aggregation(
#     418         prompt,
#     419         stop=stop,
#     420         images=images,
#     421         run_manager=run_manager,
#     422         verbose=self.verbose,
#     423         **kwargs,
#     424     )
#     425     generations.append([final_chunk])
#     426 return LLMResult(generations=generations)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_community\llms\ollama.py:326, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     317 def _stream_with_aggregation(
#     318     self,
#     319     prompt: str,
#    (...)
#     323     **kwargs: Any,
#     324 ) -> GenerationChunk:
#     325     final_chunk: Optional[GenerationChunk] = None
# --> 326     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     327         if stream_resp:
#     328             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_community\llms\ollama.py:172, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     164 def _create_generate_stream(
#     165     self,
#     166     prompt: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> Iterator[str]:
#     171     payload = {"prompt": prompt, "images": images}
# --> 172     yield from self._create_stream(
#     173         payload=payload,
#     174         stop=stop,
#     175         api_url=f"{self.base_url}/api/generate",
#     176         **kwargs,
#     177     )
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\langchain_community\llms\ollama.py:231, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     224 else:
#     225     request_payload = {
#     226         "prompt": payload.get("prompt"),
#     227         "images": payload.get("images", []),
#     228         **params,
#     229     }
# --> 231 response = requests.post(
#     232     url=api_url,
#     233     headers={
#     234         "Content-Type": "application/json",
#     235         **(self.headers if isinstance(self.headers, dict) else {}),
#     236     },
#     237     json=request_payload,
#     238     stream=True,
#     239     timeout=self.timeout,
#     240 )
#     241 response.encoding = "utf-8"
#     242 if response.status_code != 200:
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Aravind\anaconda3\envs\tf_torch\lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002C8377E26A0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(result["result"])
# Out:
# ('The LeBron James statistics show that he averages 26.3 points per game (13th '
#  'in the league), 6.7 rebounds (32nd in the league), and 9.7 assists per game '
#  '(5th in the league). His shooting efficiency is at 62.7%, with a field goal '
#  'percentage of 1.7 steals per game (17th in the league) and 0 blocks on '
#  'record according to the provided context.')
